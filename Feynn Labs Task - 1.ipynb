# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_absolute_error

# %%
file_path = r'C:\Users\Biki\.vscode\Project Files\Heart Disease Indicators.csv'
heart_data = pd.read_csv(file_path)

# %%
heart_data.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# 1              Yes  Very good        7.0     No            No         No
# 2              Yes       Fair        8.0    Yes            No         No
# 3               No       Good        6.0     No            No        Yes
# 4              Yes  Very good        8.0     No            No         No

# %%
file_path = r'C:\Users\Biki\.vscode\Project Files\Heart Disease Indicators modified+++.csv'
heart_data = pd.read_csv(file_path)

# %%
heart_data.head() #no = 0 yes = 1 female = 0 male = 1
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  16.60        1                0       0               3
# 1             0  20.34        0                0       1               0
# 2             0  26.58        1                0       0              20
# 3             0  24.21        0                0       0               0
# 4             0  23.71        0                0       0              28
#
#    MentalHealth  DiffWalking  Sex  AgeCategory   Race Diabetic  \
# 0            30            0    0           57  White        1
# 1             0            0    0           80  White        0
# 2            30            0    1           67  White        1
# 3             0            0    0           77  White        0
# 4             0            1    0           42  White        0
#
#    PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  SkinCancer
# 0                 1  Very good          5       1              0           1
# 1                 1  Very good          7       0              0           0
# 2                 1       Fair          8       1              0           0
# 3                 0       Good          6       0              0           1
# 4                 1  Very good          8       0              0           0

# %%
heart_data.drop(['Race', 'GenHealth'], axis = 1)
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0                  0  16.60        1                0       0               3
# 1                  0  20.34        0                0       1               0
# 2                  0  26.58        1                0       0              20
# 3                  0  24.21        0                0       0               0
# 4                  0  23.71        0                0       0              28
# ...              ...    ...      ...              ...     ...             ...
# 319790             1  27.41        1                0       0               7
# 319791             0  29.84        1                0       0               0
# 319792             0  24.24        0                0       0               0
# 319793             0  32.81        0                0       0               0
# 319794             0  46.56        0                0       0               0
#
#         MentalHealth  DiffWalking  Sex  AgeCategory Diabetic  \
# 0                 30            0    0           57        1
# 1                  0            0    0           80        0
# 2                 30            0    1           67        1
# 3                  0            0    0           77        0
# 4                  0            1    0           42        0
# ...              ...          ...  ...          ...      ...
# 319790             0            1    1           62        1
# 319791             0            0    1           37        0
# 319792             0            0    0           47        0
# 319793             0            0    0           27        0
# 319794             0            0    0           80        0
#
#         PhysicalActivity  SleepTime  Asthma  KidneyDisease  SkinCancer
# 0                      1          5       1              0           1
# 1                      1          7       0              0           0
# 2                      1          8       1              0           0
# 3                      0          6       0              0           1
# 4                      1          8       0              0           0
# ...                  ...        ...     ...            ...         ...
# 319790                 0          6       1              0           0
# 319791                 1          5       1              0           0
# 319792                 1          6       0              0           0
# 319793                 0         12       0              0           0
# 319794                 1          8       0              0           0
#
# [319795 rows x 16 columns]

# %%
y = heart_data.HeartDisease

# %%
disease_metrics = ['BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
       'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
        'PhysicalActivity', 'SleepTime',
       'Asthma', 'KidneyDisease', 'SkinCancer']

# %%
X = heart_data[disease_metrics]

# %%
train_X, val_X, train_y, val_y = train_test_split(X, y)

# %%
heart_model = DecisionTreeRegressor()
heart_model.fit(train_X, train_y)
preds = heart_model.predict(val_X)
mae = mean_absolute_error(val_y, preds)
print(mae)
# Out:
# 0.14256827759578805

# %%
def tree_depth_error(max_nodes, train_X, val_X, train_y, val_y):
    heart_model = DecisionTreeRegressor(max_leaf_nodes=max_nodes)
    heart_model.fit(train_X, train_y)
    preds = heart_model.predict(val_X)
    mae = mean_absolute_error(val_y, preds)
    return mae

# %%
rel = {}
for nodes in (5, 50, 500, 5000, 50000):
    my_mae = tree_depth_error(nodes, train_X, val_X, train_y, val_y)
    rel[my_mae] = nodes
best_tree_size = rel[min(rel)]
tree_error = min(rel)
print("best tree size: %d \t mae: %18.17f" %(best_tree_size, min(rel)))
# Out:
# best tree size: 500 	 mae: 0.13482651445379099

# %%
forest_model = RandomForestRegressor()
forest_model.fit(train_X, train_y)
forest_preds = forest_model.predict(val_X)
forest_model_error = mean_absolute_error(val_y, forest_preds)
print("forest error: %18.17f" %(forest_model_error))
# Out:
# forest error: 0.14149486955498383

# %%
lr_model = LinearRegression()
lr_model.fit(train_X, train_y)
lr_preds = lr_model.predict(val_X)
lr_error = mean_absolute_error(val_y, lr_preds)
print("error: %18.17f" %(lr_error))
# Out:
# error: 0.14783349717044031

# %%
nnr_model = MLPRegressor()
nnr_model.fit(train_X, train_y)
nnr_ans = nnr_model.predict(val_X)
nnr_error = mean_absolute_error(val_y, nnr_ans)
print("error: %18.17f" %(nnr_error))
# Out:
# error: 0.12926040429318297

# %%
errors = {'Decision Tree': [tree_error], 'Random Forest': [forest_model_error], 
            'Linear Regression': [lr_error], 'Neural Network Regression': [nnr_error]}
errors_df = pd.DataFrame(errors)
errors_df
# Out:
#    Decision Tree  Random Forest  Linear Regression  Neural Network Regression
# 0       0.134827       0.141495           0.147833                    0.12926

# %%
f_model = DecisionTreeRegressor(max_leaf_nodes=500)
f_model.fit(X, y)
# Out:
# DecisionTreeRegressor(max_leaf_nodes=500)

# %%
def final_model(data):
    f_ans = f_model.predict(data)
    return f_ans

# %%
my_data = {'BMI': [23.5], 'Smoking': [0],
            'AlcoholDrinking': [0], 'Stroke': [0], 'PhysicalHealth': [30], 
            'MentalHealth': [30], 'DiffWalking': [0], 'Sex': [0], 'AgeCategory': [53], 
            'PhysicalActivity': [1], 'SleepTime': [5], 'Asthma': [0], 
            'KidneyDisease': [0], 'SkinCancer': [0]}

df = pd.DataFrame(my_data)
df
# Out:
#     BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  MentalHealth  \
# 0  23.5        0                0       0              30            30
#
#    DiffWalking  Sex  AgeCategory  PhysicalActivity  SleepTime  Asthma  \
# 0            0    0           53                 1          5       0
#
#    KidneyDisease  SkinCancer
# 0              0           0

# %%
print(final_model(df))
# Out:
# [0.0711575]
